# %%
import pandas as pd

orders = pd.read_csv("../data/raw/olist_orders_dataset.csv")

orders.head()
# Out:
# Running cells with 'venv (Python 3.13.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/luis3/OneDrive - Escuela Politécnica Nacional/Documentos/GitHub/Prueba-T-cnica-Data-Engineer-Intern_MateoCoronado-/venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
